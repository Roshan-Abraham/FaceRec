# %%
import pyrebase

config = {
    "apiKey": "AIzaSyBqDoFdN3zUZ2G4ke8QoBrjTylxrRBkhpg",
    "authDomain": "minglewise2019.firebaseapp.com",
    "databaseURL": "https://minglewise2019.firebaseio.com",
    "projectId": "minglewise2019",
    "storageBucket": "minglewise2019.appspot.com",
    "messagingSenderId": "316217858377",
    "appId": "1:316217858377:web:4a075efa015035ce4d2298",
    "measurementId": "G-4B2T0G8HKE"
}

firebase = pyrebase.initialize_app(config)
storage = firebase.storage()

CloudPath = "user-image-url/verify1.png"
LocalTests = "ImgTmpStore/AuthDP.png"

storage.child(CloudPath).download(LocalTests)

# %%
img = storage.child(CloudPath).download(LocalTests)

# %%
type(img)
# Out:
# NoneType

# %%
import cv2
from matplotlib import pyplot as plt

img = LocalTests
img = cv2.imread(img, 0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
print('status')
# Out:
# status

# %%
db = firebase.database()
data = db.child("ProUsers").get()
print(data.val())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pyrebase\pyrebase.py in raise_detailed_error(request_object)
#     443     try:
# --> 444         request_object.raise_for_status()
#     445     except HTTPError as e:
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\models.py in raise_for_status(self)
#     861         if http_error_msg:
# --> 862             raise HTTPError(http_error_msg, response=self)
#     863
#
# HTTPError: 401 Client Error: Unauthorized for url: https://minglewise2019.firebaseio.com/ProUsers.json
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21928/3948012949.py in <module>
#       1 db = firebase.database()
# ----> 2 data = db.child("ProUsers").get()
#       3 print(data.val())
#
# ~\AppData\Roaming\Python\Python39\site-packages\pyrebase\pyrebase.py in get(self, token, json_kwargs)
#     262         # do request
#     263         request_object = self.requests.get(request_ref, headers=headers)
# --> 264         raise_detailed_error(request_object)
#     265         request_dict = request_object.json(**json_kwargs)
#     266
#
# ~\AppData\Roaming\Python\Python39\site-packages\pyrebase\pyrebase.py in raise_detailed_error(request_object)
#     446         # raise detailed error message
#     447         # TODO: Check if we get a { "error" : "Permission denied." } and handle automatically
# --> 448         raise HTTPError(e, request_object.text)
#     449
#     450
#
# HTTPError: [Errno 401 Client Error: Unauthorized for url: https://minglewise2019.firebaseio.com/ProUsers.json] {
#   "error" : "Permission denied"
# }
